# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sqlite3
import sqlalchemy

# %%
path = 'sqlite:////Users/pascal/Coding/uni/Masterarbeit/testpanda.sqlite'
con = sqlalchemy.create_engine(path, echo=True)

# %%
cows = pd.read_sql_table("Cow", con)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-26-fd0686dcfeed> in <module>()
# ----> 1 cows = pd.read_sql_table("Cow", con)
#
# /Users/pascal/Coding/anaconda2/lib/python2.7/site-packages/pandas/io/sql.py in read_sql_table(table_name, con, schema, index_col, coerce_float, parse_dates, columns, chunksize)
#     355     meta = MetaData(con, schema=schema)
#     356     try:
# --> 357         meta.reflect(only=[table_name], views=True)
#     358     except sqlalchemy.exc.InvalidRequestError:
#     359         raise ValueError("Table %s not found" % table_name)
#
# /Users/pascal/Coding/anaconda2/lib/python2.7/site-packages/sqlalchemy/sql/schema.py in reflect(self, bind, schema, views, only, extend_existing, autoload_replace, **dialect_kwargs)
#    3600             bind = _bind_or_error(self)
#    3601
# -> 3602         with bind.connect() as conn:
#    3603
# ...
